# %% [markdown]
# # Battle of neighborhoods - getting data and coding

# %%
#Import stats packages
import numpy as np 
import pandas as pd 
from sklearn.cluster import KMeans

#Import HTML/JSON
import requests 
from bs4 import BeautifulSoup
import json 
from pandas.io.json import json_normalize 

#Plot
import matplotlib.cm as cm
import matplotlib.colors as colors


#Geo
from geopy.geocoders import Nominatim 
import geocoder
import folium

# %% [markdown]
# ## Getting Data and Merging with coordinates

# %%
#Getting data
URL="https://en.wikipedia.org/wiki/List_of_neighbourhoods_of_Chennai"
r = requests.get(URL) 
soup = BeautifulSoup(r.content, 'html5lib') 
neighborhood=[]
# append the data into the list
for row in soup.find_all('li')[11:]:
    neighborhood.append(row.text)

# %%
#using Pandas to clean the data/getting data source with co-ordinates
df = pd.DataFrame({"Neighborhood": neighborhood})
df2=pd.read_csv('df2.csv')

# %% [markdown]
# ## Map of Neighborhood

# %%
# create map of Chennai using latitude and longitude values
map_ch = folium.Map(location=[13.0801721, 80.2838331], zoom_start=11)

# add markers to map
for lat, lng, neighborhood in zip(df2['Latitude'], df2['Longitude'], df2['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_ch)  
    
map_ch
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Merging Data with 4Square API

# %%
# Using code from coursera API classes/ref github

radius = 1000
LIMIT = 100
venues = []
for lat, long, neighborhood in zip(df2['Latitude'], df2['Longitude'], df2['Neighborhood']):

  #4Square API - 
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
  CLIENT_ID,
  CLIENT_SECRET,
  VERSION,
  lat,
  long,
  radius,
  LIMIT)

    results = requests.get(url).json()
    for venue in results["response"]["groups"][0]['items']:
          venues.append((
    neighborhood,
    lat,
    long,
    venue['venue']['name'],
    venue['venue']['location']['lat'],
    venue['venue']['location']['lng'],
    venue['venue']['categories'][0]['name']))

# %%
df3 = pd.DataFrame(venues)
# define the column names
df3.columns = ['Neighborhood', 'Latitude', 'Longitude', 'Name', 'Lat', 'Long', 'Cat']

# %%
df3.shape

# %% [markdown]
# ## Analyzing Data

# %%
df3.groupby(["Neighborhood"]).count().head(5)
# Out:
#                  Latitude  Longitude  Name  Lat  Long  Cat
# Neighborhood
# Alapakkam               8          8     8    8     8    8
# Alwarthirunagar        15         15    15   15    15   15
# Ambattur               12         12    12   12    12   12
# Aminjikarai            18         18    18   18    18   18
# Anna Nagar             70         70    70   70    70   70

# %%
# print out the list of categories
df3['Cat'].unique()
# Out:
# array(['Indian Restaurant', 'Multiplex', 'Bus Station',
#        'Department Store', 'Electronics Store', 'Fried Chicken Joint',
#        'Dessert Shop', 'Accessories Store', 'Bakery', 'Ice Cream Shop',
#        'ATM', 'Train Station', 'Boutique', 'Indie Movie Theater',
#        'Vegetarian / Vegan Restaurant', 'Chinese Restaurant',
#        'Farmers Market', 'Currency Exchange', 'Beach', 'Harbor / Marina',
#        'Mobile Phone Shop', 'Platform', 'Coffee Shop', 'Scenic Lookout',
#        'Park', "Women's Store", 'Food & Drink Shop', 'Farm', 'Bookstore',
#        'Bike Rental / Bike Share', 'Restaurant', 'Video Store', 'Market',
#        'Convenience Store', 'Snack Place', 'Gym', 'Food Truck',
#        'Fast Food Restaurant', 'Health & Beauty Service',
#        'Business Service', 'Miscellaneous Shop',
#        'South Indian Restaurant', 'Pharmacy', 'IT Services', 'Bus Stop',
#        'Museum', 'Hotel', 'Italian Restaurant', 'Pizza Place', 'Café',
#        'Sandwich Place', 'Diner', 'Juice Bar', 'Yoga Studio',
#        'Historic Site', 'Supermarket', 'Concert Hall',
#        'Himalayan Restaurant', 'Light Rail Station', 'Nightclub',
#        'Campground', 'Metro Station', 'Furniture / Home Store',
#        'Outlet Store', 'Soccer Stadium', 'Clothing Store',
#        'Halal Restaurant', 'Shopping Plaza', 'Tailor Shop',
#        'Asian Restaurant', 'Thai Restaurant', 'Grocery Store',
#        'Intersection', 'Pet Store', 'Leather Goods Store',
#        'Fruit & Vegetable Store', 'Movie Theater', 'Flea Market', 'River',
#        'Breakfast Spot', 'Motorcycle Shop', 'Theme Park',
#        'Cricket Ground', 'BBQ Joint', 'Andhra Restaurant', 'Bank',
#        'Gas Station', 'Buffet', 'Shopping Mall', 'Shoe Store',
#        'Indian Sweet Shop', 'American Restaurant', 'Burger Joint',
#        'Middle Eastern Restaurant', 'New American Restaurant',
#        'Paper / Office Supplies Store', 'Hotel Bar', 'Bistro',
#        "Men's Store", 'Food', 'Event Space',
#        'Multicuisine Indian Restaurant', 'Pub', 'Food Court',
#        'Video Game Store', 'Flower Shop', 'Antique Shop', 'Bus Line',
#        'Sculpture Garden', 'Jewelry Store', 'Arcade',
#        'Punjabi Restaurant', 'Print Shop', 'Lake', 'Deli / Bodega',
#        'Music Store', 'Tea Room', 'Gym Pool', 'Gym / Fitness Center',
#        'Cafeteria', 'Modern European Restaurant', 'Tennis Stadium',
#        'Pool', 'Bengali Restaurant', 'Bar', 'Lounge', 'Amphitheater',
#        'Hookah Bar', 'Recreation Center', 'Cosmetics Shop',
#        'Chettinad Restaurant', 'Hospital'], dtype=object)

# %% [markdown]
# ## Clustering Model

# %%
#after preprocessing and transforming
df4=pd.read_csv('tran.csv')
X=df4.drop(["Neighborhood"], 1)


clusterNum = 5
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
labels = k_means.labels_
print(labels)
# Out:
# [4 0 0 4 3 0 0 0 4 4 4 0 4 4 4 4 4 4 4 4 4 0 4 0 4 4 4 4 4 0 0 4 1 4 4 4 4
#  4 4 4 4 4 4 4 4 4 4 4 0 0 4 4 0 4 4 4 4 4 0 4 4 4 4 4 0 4 4 0 4 4 2 4 4 4
#  0 4 4 0 4 0 2 4 4 4 4 4 4 4 2 0 4 4 4 4 4]

# %%
# add clustering labels
df4.insert(0, 'Cluster Labels', labels)
df5=pd.read_csv('meta.csv')

# %%
ch_merged=pd.merge(df5,df4,on='Neighborhood')

# %% [markdown]
# ### Visual View of the clusters

# %%
# create map
map_clusters = folium.Map(location=[13.0801721, 80.2838331], zoom_start=11)

# set color scheme for the clusters
x = np.arange(clusterNum)
ys = [i+x+(i*x)**2 for i in range(clusterNum)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(ch_merged['Latitude'], ch_merged['Longitude'], ch_merged['Neighborhood'], ch_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' - Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ch_merged.groupby('Cluster Labels').mean()
# Out:
#                  Latitude  Longitude  Accessories_Store  American_Restaurant  \
# Cluster Labels
# 0               13.064119  80.206926           0.000000                  0.0
# 1               13.052510  80.241760           0.000000                  0.0
# 2               13.073453  80.220493           0.000000                  0.0
# 3               13.083590  80.210200           0.000000                  1.0
# 4               13.110497  80.200305           0.028571                  0.0
#
#                 Amphitheater  Andhra_Restaurant  Antique_Shop  Arcade  \
# Cluster Labels
# 0                        0.0               0.05          0.05    0.05
# 1                        1.0               0.00          0.00    0.00
# 2                        0.0               0.00          0.00    0.00
# 3                        0.0               0.00          0.00    0.00
# 4                        0.0               0.00          0.00    0.00
#
#                 Asian_Restaurant  ATM  ...  Tea_Room  Tennis_Stadium  \
# Cluster Labels                         ...
# 0                       0.400000  0.0  ...      0.05             0.0
# 1                       2.000000  0.0  ...      0.00             1.0
# 2                       0.666667  0.0  ...      0.00             0.0
# 3                       1.000000  0.0  ...      0.00             0.0
# 4                       0.042857  0.3  ...      0.00             0.0
#
#                 Thai_Restaurant  Theme_Park  Train_Station  \
# Cluster Labels
# 0                      0.000000        0.05       0.300000
# 1                      1.000000        0.00       0.000000
# 2                      0.000000        0.00       0.333333
# 3                      0.000000        0.00       0.000000
# 4                      0.014286        0.00       0.214286
#
#                 Vegetarian___Vegan_Restaurant  Video_Game_Store  Video_Store  \
# Cluster Labels
# 0                                    0.900000          0.000000     0.100000
# 1                                    0.000000          0.000000     0.000000
# 2                                    0.666667          0.000000     0.000000
# 3                                    4.000000          0.000000     0.000000
# 4                                    0.057143          0.014286     0.028571
#
#                 Women_s_Store  Yoga_Studio
# Cluster Labels
# 0                    0.000000     0.000000
# 1                    0.000000     0.000000
# 2                    0.000000     0.333333
# 3                    0.000000     0.000000
# 4                    0.014286     0.000000
#
# [5 rows x 134 columns]

# %% [markdown]
# ## Final Cluster

# %%
#cl4=pd.read_csv('ana.csv')
cl4.groupby('Cat').mean()
# Out:
#                                count
# Cat
# American Restaurant                1
# Asian Restaurant                   1
# BBQ Joint                          1
# Bakery                             1
# Bistro                             1
# Bookstore                          1
# Burger Joint                       1
# Cafe                               2
# Chinese Restaurant                 5
# Clothing Store                     3
# Coffee Shop                        2
# Department Store                   4
# Electronics Store                  2
# Farmers Market                     1
# Fast Food Restaurant               5
# Gym                                1
# Hotel                              1
# Hotel Bar                          1
# Ice Cream Shop                     2
# Indian Restaurant                 12
# Indian Sweet Shop                  1
# Juice Bar                          1
# Market                             1
# Men's Store                        1
# Middle Eastern Restaurant          1
# Mobile Phone Shop                  1
# New American Restaurant            1
# Paper / Office Supplies Store      1
# Park                               1
# Pizza Place                        2
# Restaurant                         1
# Sandwich Place                     1
# Shoe Store                         1
# Snack Place                        1
# South Indian Restaurant            1
# Vegetarian / Vegan Restaurant      4
