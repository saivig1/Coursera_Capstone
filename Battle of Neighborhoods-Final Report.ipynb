# %% [markdown]
# # BATTLE OF NEIGHBORHOODS-FINAL REPORT

# %% [markdown]
# #  Business Problem

# %% [markdown]
# ## Introduction:

# %% [markdown]
# Mr.T is a wealthy investor looking to open two businesses in Chennai India,he is clear about the type of businesess  to venture:<br>
#
# 1.Health bar - Fruit & Vegetable Juice bar / Kombucha
# 2.Multi cusine restaurent - Food from around the world

# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# Opening the right restaurent in the right neighborhood is crucial,entering the right neighborhood affects the captial investment and will greatly determine Mr.T's future.
# The objective for this project is to recommend neighborhood or neighborhoods that will be the best choice to start a health bar and restaurant.

# %% [markdown]
# # Data

# %% [markdown]
# To solve this business problem with data science we will be using the following data sources
# - Chennai's neighborhood information from wikipedia
# - Foursquare API to get information about types of business and restaurents

# %% [markdown]
# ## Methodology:

# %% [markdown]
# We will utilize the neighborhood information and the Foursquare API to develop a clustering model to understand the clusters in Chennai's neighborhood and utilize that model data to recommend the right neighborhood.
#
#
# 1.First we start by taking the neighborhood information.
# 2.Then we merge the coordinates from external data
# 3.Then we utilize 4Square API to get the Venue information
# 4.We then proceed to run a k-Means cluster model
# 5.We analyze the results from the clusters to identify neighborhoods that fit our business goals.

# %% [markdown]
# # Results

# %% [markdown]
# We started out with the Data cleansing and the plotting of the intial neighborhoods:

# %%
from IPython.display import Image
Image("N0.png")

# %%
from IPython.display import Image
Image("N1.png")

# %% [markdown]
# ## Cluster Results

# %%
from IPython.display import Image
Image("N3.png")

# %%
from IPython.display import Image
Image("C2.png")

# %% [markdown]
# # Discussion

# %% [markdown]
# From the cluster analysis it is evident that most of the neighborhoods are not unique except cluster 3 and 5
# Further Analysing the results we can see that Neighborhood-Anna Nagar is very unique

# %%
from IPython.display import Image
Image("R1.png")

# %% [markdown]
# # Conclusion

# %% [markdown]
# The conclusion of this report is that Mr.T should open his businesses in Neighborhood -ANNA NAGAR
